# %% [markdown]
# # Hands sync
#
# This is the fourth part of my project, in this part we will try to make a classifier for hand movement, to see if it was alone, syncronized or not

# %%
import cv2
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import glob
import random
# %matplotlib inline
from PIL import Image

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#function to add tags to the rows. 0 will be alone, 1 is spontanious and 2 is syncronized
def add_tag(dataframe, path):
    if "Spontan" in path:
        tags = np.ones(dataframe.shape[0],dtype=int)
        dataframe['Label'] = tags
    elif "alone" in path:
        tags = np.zeros(dataframe.shape[0],dtype=int)
        dataframe['Label'] = tags
    else:
        tags = np.full(dataframe.shape[0], 2,dtype = int)
        dataframe['Label'] = tags

# %%
#function to merge all rows in a file that have the same second but diffrent hands
def merge_right_left(path,RightHand):
    df = pd.read_csv(path)
    if "Alone" in path :
        try:
            df = df.loc[df[' Hand Type'] == "left"]
        finally:
            for column in RightHand.columns: #lets rename the columns so we know which is right nad which is left
                RightHand = RightHand.rename(columns = {column: column + "_R"})
            for column in df.columns:
                df = df.rename(columns = {column: column + "_L"})
            to_merge = [df,RightHand]
            merged = pd.concat(to_merge,axis = 1)
            add_tag(merged, path)
    else:
        right = df.loc[df[" Hand Type"] == "right"]
        left = df.loc[df[" Hand Type"] == "left"]
        for column in right.columns: #lets rename the columns so we know which is right nad which is left
            right = right.rename(columns = {column: column + "_R"})
        for column in left.columns:
            left = left.rename(columns = {column: column + "_L"})
        merged = right.merge(left, left_on="Time_R", right_on = "Time_L")
        add_tag(merged, path)
    return merged

# %% [markdown]
# First, lets get one of the files and see what it looks like

# %%
df = pd.read_csv("C:\\Users\\magshimim\\Desktop\\jupiter\\extraFiles\\Training\\All in one\\Evyatar636771052727603804Spontan.csv")

# %%
df.head(20)
# Out:
#         Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0   335.9984     128556      right         2    128.63570     224.0294
# 1   335.9984     128556       left         2    -93.24845     143.9423
# 2   336.0150     128558      right         2    129.15550     221.9923
# 3   336.0150     128558       left         2    -94.86554     148.5542
# 4   336.0315     128560      right         2    129.87070     220.7944
# 5   336.0315     128560       left         2    -95.16259     152.5339
# 6   336.0481     128562      right         2    131.07210     219.2134
# 7   336.0481     128562       left         2    -95.37997     156.0973
# 8   336.0651     128564      right         2    132.46290     216.8003
# 9   336.0651     128564       left         2    -97.10074     161.7751
# 10  336.0816     128566      right         2    134.08500     214.4446
# 11  336.0816     128566       left         2    -98.59742     166.4238
# 12  336.0978     128568      right         2    136.61990     213.6942
# 13  336.0978     128568       left         2    -99.88398     170.7007
# 14  336.1146     128570      right         2    138.58170     212.2641
# 15  336.1146     128570       left         2   -101.38280     175.6262
# 16  336.1309     128572      right         2    140.85970     212.0737
# 17  336.1309     128572       left         2   -102.09680     179.3425
# 18  336.1475     128574      right         2    142.67590     210.1393
# 19  336.1475     128574       left         2   -103.95700     184.4355
#
#      Position Z   Velocity X   Velocity Y   Velocity Z  ...       Yaw  \
# 0     -12.29588    -18.26243   -140.54450  -117.577900  ... -1.588251
# 1     -37.81597   -109.09820    240.38980   -67.629590  ...  0.873458
# 2     -15.00181     47.36464    -64.25022  -168.858500  ... -1.528183
# 3     -39.00158    -80.99012    278.60220   -66.793560  ...  0.879703
# 4     -18.38681     35.05422    -84.74242  -205.720300  ... -1.461710
# 5     -39.94570    -11.37293    232.80310   -53.320790  ...  0.895820
# 6     -22.05511     36.51635   -153.35370  -212.825900  ... -1.380241
# 7     -40.18840     -3.05615    203.81210    19.494730  ...  0.918827
# 8     -25.45043     98.73232    -65.53646  -218.720100  ... -1.287442
# 9     -40.36338    -98.92747    316.64520    -7.328697  ...  0.946004
# 10    -28.93817    138.87250    -93.84897  -209.651200  ... -1.200900
# 11    -40.22689    -40.49903    197.51350    28.777420  ...  0.976456
# 12    -32.39749    110.67480    -81.51698  -188.235100  ... -1.093543
# 13    -40.10544    -79.72356    263.82490    -0.122563  ...  1.011048
# 14    -35.02980    147.63820    -39.37857  -164.049900  ... -1.002105
# 15    -39.80783   -108.68490    295.52900    31.128340  ...  1.040905
# 16    -38.90633     95.30194    -60.22543  -199.949900  ... -0.901307
# 17    -39.34177    -14.09057    205.20360    23.955750  ...  1.072629
# 18    -42.26403    134.42280    -89.76099  -186.501600  ... -0.798287
# 19    -38.25431   -123.03590    297.94170    57.522810  ...  1.102318
#
#      Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# 0       177.5125      173.5658    -14.569630      276.8753     -33.68264
# 1      -147.0455      109.9380     -5.326688     -329.8577     -34.41571
# 2       177.7894      171.1952    -14.677850      276.0645     -33.15913
# 3      -148.2022      113.0909     -7.375025     -326.9279     -39.97873
# 4       178.3730      169.9159    -15.246240      276.1767     -30.72506
# 5      -148.3343      115.9295     -9.437292     -322.0559     -44.42383
# 6       179.5035      168.4482    -15.568560      276.6018     -31.22840
# 7      -148.3562      118.3093    -10.919770     -314.2976     -49.04110
# 8       179.5375      165.1393    -15.531890      271.5673     -37.88867
# 9      -149.2292      121.7602    -12.780660     -299.9106     -56.55378
# 10      181.0919      163.4637    -15.320050      268.2274     -43.06868
# 11     -150.8117      125.7308    -14.018070     -293.6814     -57.60085
# 12      182.1657      162.4424    -14.708730      265.9359     -48.16333
# 13     -152.7514      130.1605    -15.206720     -290.8440     -56.34965
# 14      183.6304      162.1000    -13.224820      262.5406     -53.62193
# 15     -154.6503      134.8011    -16.357980     -291.6137     -53.14043
# 16      184.1823      162.3100    -12.894590      258.8384     -55.66012
# 17     -155.9273      138.5645    -17.284910     -290.9996     -52.20217
# 18      183.7722      160.8939    -11.876580      254.7479     -57.25224
# 19     -157.1862      141.8336    -18.355700     -287.4631     -55.13954
#
#      Elbow Pos Z   Grab Strenth   Grab Angle   Pinch Strength
# 0       91.61740       0.000000     1.250576              0.0
# 1       93.88171       0.000000     0.014736              0.0
# 2       97.88171       0.000000     1.069930              0.0
# 3       85.98000       0.000000     0.000000              0.0
# 4      104.13920       0.000000     0.916969              0.0
# 5       81.02193       0.000000     0.000000              0.0
# 6      105.96400       0.000000     0.798334              0.0
# 7       81.41824       0.000000     0.000000              0.0
# 8      104.38140       0.000000     0.728858              0.0
# 9       85.03669       0.000000     0.000000              0.0
# 10     102.24200       0.000000     0.802890              0.0
# 11      86.21560       0.000000     0.000000              0.0
# 12      97.97150       0.000000     1.178434              0.0
# 13      85.85482       0.000000     0.000000              0.0
# 14      93.10597       0.000000     1.053544              0.0
# 15      83.58225       0.000000     0.000000              0.0
# 16      91.91254       0.042992     1.080393              0.0
# 17      79.83644       0.000000     0.000000              0.0
# 18      95.09887       0.000000     1.000203              0.0
# 19      72.74039       0.000000     0.000000              0.0
#
# [20 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Time               0
#  Frame ID          0
#  Hand Type         0
#  # hands           0
#  Position X        0
#  Position Y        0
#  Position Z        0
#  Velocity X        0
#  Velocity Y        0
#  Velocity Z        0
#  Pitch             0
#  Roll              0
#  Yaw               0
#  Wrist Pos X       0
#  Wrist Pos Y       0
#  Wrist Pos Z       0
#  Elbow pos X       0
#  Elbow Pos Y       0
#  Elbow Pos Z       0
#  Grab Strenth      0
#  Grab Angle        0
#  Pinch Strength    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Time', ' Frame ID', ' Hand Type', ' # hands', ' Position X',
#        ' Position Y', ' Position Z', ' Velocity X', ' Velocity Y',
#        ' Velocity Z', ' Pitch', ' Roll', ' Yaw', ' Wrist Pos X',
#        ' Wrist Pos Y', ' Wrist Pos Z', ' Elbow pos X', ' Elbow Pos Y',
#        ' Elbow Pos Z', ' Grab Strenth', ' Grab Angle', ' Pinch Strength'],
#       dtype='object')

# %% [markdown]
# now lets see how one of the aloen files looks like and how the HandRight looks right

# %%
HandRight = pd.read_csv("C:\\Users\\magshimim\\Desktop\\jupiter\\extraFiles\\HandRight.csv")

# %%
HandRight.head()
# Out:
#        Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0  128.2883      15478      right         1     15.67167     226.2064
# 1  128.3048      15480      right         1     16.24119     222.9389
# 2  128.3218      15482      right         1     16.72461     220.9709
# 3  128.3384      15484      right         1     17.09016     219.7124
# 4  128.3551      15486      right         1     17.46017     219.3652
#
#     Position Z   Velocity X   Velocity Y   Velocity Z  ...       Yaw  \
# 0     20.26470     34.26665  -195.214700   -35.043020  ... -0.277800
# 1     20.11781     36.16443  -180.093900    -4.052799  ... -0.277763
# 2     19.94972     26.35298   -95.088190   -11.157620  ... -0.278792
# 3     19.67679     19.46804   -61.755180   -21.303780  ... -0.279768
# 4     19.13128     21.94964    -8.355943   -35.081790  ... -0.278629
#
#     Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# 0      46.88831      207.3548      86.23589      203.8337      49.33507
# 1      47.54861      205.6568      86.42250      203.9553      47.88272
# 2      48.15030      204.5182      86.35149      204.6231      45.35921
# 3      48.64175      203.9989      86.16056      204.9939      44.18692
# 4      48.93135      203.3777      85.59017      204.5952      42.68003
#
#     Elbow Pos Z   Grab Strenth   Grab Angle   Pinch Strength
# 0      237.4553            0.0     0.206389              0.0
# 1      238.4482            0.0     0.243050              0.0
# 2      236.8544            0.0     0.281134              0.0
# 3      236.0927            0.0     0.277691              0.0
# 4      235.2896            0.0     0.283008              0.0
#
# [5 rows x 22 columns]

# %%
HandRight = HandRight.loc[HandRight[' Hand Type'] == "right"]

# %%
HandRight.isnull().sum()
# Out:
# Time                 0
#  Frame ID            0
#  Hand Type           0
#  # hands             0
#  Position X          0
#  Position Y          0
#  Position Z          0
#  Velocity X          0
#  Velocity Y          0
#  Velocity Z          0
#  Pitch               0
#  Roll                0
#  Yaw                 0
#  Wrist Pos X       384
#  Wrist Pos Y       384
#  Wrist Pos Z       384
#  Elbow pos X       384
#  Elbow Pos Y       384
#  Elbow Pos Z       384
#  Grab Strenth        0
#  Grab Angle          0
#  Pinch Strength      0
# dtype: int64

# %%
alone_test = pd.read_csv("C:\\Users\\magshimim\\Desktop\\jupiter\\extraFiles\\Training\\All in one\\Evyatar636771054555711409Alone.csv")

# %%
alone_test.head()
# Out:
#        Time   Frame ID  Hand Type   # hands   Position X   Position Y  \
# 0  518.8087     149620       left         1    -97.60160     164.1213
# 1  518.8252     149622       left         1    -95.78062     157.6353
# 2  518.8418     149623       left         1    -94.39360     154.6338
# 3  518.8587     149625       left         1    -92.02553     150.6723
# 4  518.8749     149627       left         1    -89.31953     148.1826
#
#     Position Z   Velocity X   Velocity Y   Velocity Z  ...       Yaw  \
# 0     42.81255     104.2589    -491.6730    -55.42755  ...  1.661706
# 1     42.18084     148.9683    -351.7386    -36.32422  ...  1.623222
# 2     41.93171     161.6958    -349.9117    -29.04277  ...  1.602898
# 3     42.10119     117.3475    -187.1781     24.42598  ...  1.567605
# 4     42.67065     155.3344    -135.6337     35.87055  ...  1.535920
#
#     Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# 0     -166.7207      164.8320      27.58547     -378.1662      65.89330
# 1     -165.4907      155.6419      29.71037     -380.3233      52.92441
# 2     -164.3658      151.5701      31.05059     -381.7444      48.55032
# 3     -162.2663      144.6214      33.94577     -383.4688      40.27151
# 4     -159.4586      138.6087      36.68195     -381.0906      29.07133
#
#     Elbow Pos Z   Grab Strenth   Grab Angle   Pinch Strength
# 0     -69.90282            0.0     0.741855              0.0
# 1     -55.71872            0.0     0.827916              0.0
# 2     -47.27909            0.0     0.920401              0.0
# 3     -30.72728            0.0     1.034603              0.0
# 4     -17.01065            0.0     1.166705              0.0
#
# [5 rows x 22 columns]

# %%
path = "C:\\Users\\magshimim\\Desktop\\jupiter\\extraFiles\\Training\\All in one"
paths = []
for file in os.listdir(path):
    paths.append(path + "\\"+file)

# %%
first_to_merge = merge_right_left(paths[0],HandRight)
i = 1
for i in range(len(paths)):
    to_merge = [first_to_merge,merge_right_left(paths[i],HandRight)]
    first_to_merge = pd.concat(to_merge,ignore_index = True)

# %%
first_to_merge
# Out:
#           Time_R   Frame ID_R  Hand Type_R   # hands_R   Position X_R  \
# 0       335.9984     128556.0        right         2.0      128.63570
# 1       336.0150     128558.0        right         2.0      129.15550
# 2       336.0315     128560.0        right         2.0      129.87070
# 3       336.0481     128562.0        right         2.0      131.07210
# 4       336.0651     128564.0        right         2.0      132.46290
# ...          ...          ...          ...         ...            ...
# 123176  856.1965      67304.0        right         2.0       97.75611
# 123177  856.2291      67306.0        right         2.0       98.93275
# 123178  856.2631      67309.0        right         2.0      101.91230
# 123179  856.2958      67311.0        right         2.0      103.84750
# 123180  856.3295      67314.0        right         2.0      106.11880
#
#          Position Y_R   Position Z_R   Velocity X_R   Velocity Y_R  \
# 0            224.0294      -12.29588      -18.26243     -140.54450
# 1            221.9923      -15.00181       47.36464      -64.25022
# 2            220.7944      -18.38681       35.05422      -84.74242
# 3            219.2134      -22.05511       36.51635     -153.35370
# 4            216.8003      -25.45043       98.73232      -65.53646
# ...               ...            ...            ...            ...
# 123176       205.9629       30.04651       28.36298       77.44335
# 123177       208.3153       34.85991       44.38393       71.36857
# 123178       212.0264       42.53568       79.95810      113.41030
# 123179       214.7484       47.07082       61.11773       95.13531
# 123180       218.0190       53.58868       25.46704       72.26683
#
#          Velocity Z_R  ...   Wrist Pos X_L   Wrist Pos Y_L   Wrist Pos Z_L  \
# 0           -117.5779  ...       -147.0455        109.9380       -5.326688
# 1           -168.8585  ...       -148.2022        113.0909       -7.375025
# 2           -205.7203  ...       -148.3343        115.9295       -9.437292
# 3           -212.8259  ...       -148.3562        118.3093      -10.919770
# 4           -218.7201  ...       -149.2292        121.7602      -12.780660
# ...               ...  ...             ...             ...             ...
# 123176       162.1428  ...       -107.8500        127.8215       32.852500
# 123177       187.5408  ...       -108.0805        128.1729       33.403910
# 123178       190.7714  ...       -109.0018        129.5246       33.898560
# 123179       155.7453  ...       -109.7250        130.7078       34.033600
# 123180       190.1636  ...       -109.5167        131.6489       33.329450
#
#          Elbow pos X_L   Elbow Pos Y_L   Elbow Pos Z_L   Grab Strenth_L  \
# 0            -329.8577      -34.415710        93.88171              0.0
# 1            -326.9279      -39.978730        85.98000              0.0
# 2            -322.0559      -44.423830        81.02193              0.0
# 3            -314.2976      -49.041100        81.41824              0.0
# 4            -299.9106      -56.553780        85.03669              0.0
# ...                ...             ...             ...              ...
# 123176       -318.7630       20.751860       138.01250              0.0
# 123177       -314.6744       14.308990       139.99090              0.0
# 123178       -304.9600       -0.548136       142.01090              0.0
# 123179       -295.5957      -14.978170       140.02630              0.0
# 123180       -282.9649      -31.354620       135.07610              0.0
#
#          Grab Angle_L   Pinch Strength_L  Label
# 0            0.014736                0.0      1
# 1            0.000000                0.0      1
# 2            0.000000                0.0      1
# 3            0.000000                0.0      1
# 4            0.000000                0.0      1
# ...               ...                ...    ...
# 123176       0.000000                0.0      2
# 123177       0.000000                0.0      2
# 123178       0.000000                0.0      2
# 123179       0.000000                0.0      2
# 123180       0.000000                0.0      2
#
# [123181 rows x 45 columns]

# %%
first_to_merge.isnull().any().sum()
# Out:
# 44

# %% [markdown]
# Lets remove all the rows that have null values

# %%
final = first_to_merge.dropna()

# %%
final.isnull().any().sum()
# Out:
# 0

# %%
final.isnull().sum()
# Out:
# Time_R               0
#  Frame ID_R          0
#  Hand Type_R         0
#  # hands_R           0
#  Position X_R        0
#  Position Y_R        0
#  Position Z_R        0
#  Velocity X_R        0
#  Velocity Y_R        0
#  Velocity Z_R        0
#  Pitch_R             0
#  Roll_R              0
#  Yaw_R               0
#  Wrist Pos X_R       0
#  Wrist Pos Y_R       0
#  Wrist Pos Z_R       0
#  Elbow pos X_R       0
#  Elbow Pos Y_R       0
#  Elbow Pos Z_R       0
#  Grab Strenth_R      0
#  Grab Angle_R        0
#  Pinch Strength_R    0
# Time_L               0
#  Frame ID_L          0
#  Hand Type_L         0
#  # hands_L           0
#  Position X_L        0
#  Position Y_L        0
#  Position Z_L        0
#  Velocity X_L        0
#  Velocity Y_L        0
#  Velocity Z_L        0
#  Pitch_L             0
#  Roll_L              0
#  Yaw_L               0
#  Wrist Pos X_L       0
#  Wrist Pos Y_L       0
#  Wrist Pos Z_L       0
#  Elbow pos X_L       0
#  Elbow Pos Y_L       0
#  Elbow Pos Z_L       0
#  Grab Strenth_L      0
#  Grab Angle_L        0
#  Pinch Strength_L    0
# Label                0
# dtype: int64

# %%
final
# Out:
#           Time_R   Frame ID_R  Hand Type_R   # hands_R   Position X_R  \
# 0       335.9984     128556.0        right         2.0      128.63570
# 1       336.0150     128558.0        right         2.0      129.15550
# 2       336.0315     128560.0        right         2.0      129.87070
# 3       336.0481     128562.0        right         2.0      131.07210
# 4       336.0651     128564.0        right         2.0      132.46290
# ...          ...          ...          ...         ...            ...
# 123176  856.1965      67304.0        right         2.0       97.75611
# 123177  856.2291      67306.0        right         2.0       98.93275
# 123178  856.2631      67309.0        right         2.0      101.91230
# 123179  856.2958      67311.0        right         2.0      103.84750
# 123180  856.3295      67314.0        right         2.0      106.11880
#
#          Position Y_R   Position Z_R   Velocity X_R   Velocity Y_R  \
# 0            224.0294      -12.29588      -18.26243     -140.54450
# 1            221.9923      -15.00181       47.36464      -64.25022
# 2            220.7944      -18.38681       35.05422      -84.74242
# 3            219.2134      -22.05511       36.51635     -153.35370
# 4            216.8003      -25.45043       98.73232      -65.53646
# ...               ...            ...            ...            ...
# 123176       205.9629       30.04651       28.36298       77.44335
# 123177       208.3153       34.85991       44.38393       71.36857
# 123178       212.0264       42.53568       79.95810      113.41030
# 123179       214.7484       47.07082       61.11773       95.13531
# 123180       218.0190       53.58868       25.46704       72.26683
#
#          Velocity Z_R  ...   Wrist Pos X_L   Wrist Pos Y_L   Wrist Pos Z_L  \
# 0           -117.5779  ...       -147.0455        109.9380       -5.326688
# 1           -168.8585  ...       -148.2022        113.0909       -7.375025
# 2           -205.7203  ...       -148.3343        115.9295       -9.437292
# 3           -212.8259  ...       -148.3562        118.3093      -10.919770
# 4           -218.7201  ...       -149.2292        121.7602      -12.780660
# ...               ...  ...             ...             ...             ...
# 123176       162.1428  ...       -107.8500        127.8215       32.852500
# 123177       187.5408  ...       -108.0805        128.1729       33.403910
# 123178       190.7714  ...       -109.0018        129.5246       33.898560
# 123179       155.7453  ...       -109.7250        130.7078       34.033600
# 123180       190.1636  ...       -109.5167        131.6489       33.329450
#
#          Elbow pos X_L   Elbow Pos Y_L   Elbow Pos Z_L   Grab Strenth_L  \
# 0            -329.8577      -34.415710        93.88171              0.0
# 1            -326.9279      -39.978730        85.98000              0.0
# 2            -322.0559      -44.423830        81.02193              0.0
# 3            -314.2976      -49.041100        81.41824              0.0
# 4            -299.9106      -56.553780        85.03669              0.0
# ...                ...             ...             ...              ...
# 123176       -318.7630       20.751860       138.01250              0.0
# 123177       -314.6744       14.308990       139.99090              0.0
# 123178       -304.9600       -0.548136       142.01090              0.0
# 123179       -295.5957      -14.978170       140.02630              0.0
# 123180       -282.9649      -31.354620       135.07610              0.0
#
#          Grab Angle_L   Pinch Strength_L  Label
# 0            0.014736                0.0      1
# 1            0.000000                0.0      1
# 2            0.000000                0.0      1
# 3            0.000000                0.0      1
# 4            0.000000                0.0      1
# ...               ...                ...    ...
# 123176       0.000000                0.0      2
# 123177       0.000000                0.0      2
# 123178       0.000000                0.0      2
# 123179       0.000000                0.0      2
# 123180       0.000000                0.0      2
#
# [115737 rows x 45 columns]
